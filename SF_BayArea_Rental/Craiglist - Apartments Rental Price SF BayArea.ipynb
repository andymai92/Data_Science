# %% [markdown]
# <b>------------------------</b><br>
# (C) 08/2017 by Andy Mai<br>
# Email: andymai.ca@aol.com<br>
# San Jose, CA - Capital of Silicon Valley<br>
# <b>------------------------</b>
# # Craigslist - Apartments' Rental Price in SF Bay Area
# ### Get information from Craigslist to Python via HTML Get and BeautifulShoup API
# In this example, we will get information about apartment rental price in SF Bay Area (California)

# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import requests
from bs4 import BeautifulSoup as bs4

# %% [markdown]
# ## We will do step by step how to get information from Craigslist.
# Assume that we would like to get data of apartments with 01 bedroom and already furnished

# %% [markdown]
# ## STEP 01: Prepare the URL in order to GET information
# * The base will be stored in <strong>url_base</strong> variable
# * The extension for HTML GET will be stored in <b>params</b>
# <br>After that you can see the full URL will be passed as below:
# <br><i>https://sfbay.craigslist.org/search/apa?s=120&is_furnished=1&bedrooms=1
# </i>

# %%
url_base = 'https://sfbay.craigslist.org/search/apa'
params = dict(bedrooms=1, is_furnished=1)
resq = requests.get(url_base, params=params)
# We have the full URL:
print (resq.url)
# Out:
# https://sfbay.craigslist.org/search/apa?is_furnished=1&bedrooms=1

# %% [markdown]
# We will use BeautifulSoup API to simplify the content of what we get from Craigslist

# %%
html = bs4(resq.text, 'html.parser')
print(html.prettify())
# Out:
# ﻿
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <title>
#    SF bay area apts/housing for rent  - craigslist
#   </title>
#   <meta content="SF bay area apts/housing for rent  - craigslist" name="description">
#    <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#    <link href="https://sfbay.craigslist.org/search/apa" rel="canonical">
#     <link href="https://sfbay.craigslist.org/search/apa?format=rss&amp;is_furnished=1&amp;min_bedrooms=1" rel="alternate" title="RSS feed for craigslist | SF bay area apts/housing for rent  - craigslist " type="application/rss+xml">
#      <link href="https://sfbay.craigslist.org/search/apa?s=120&amp;is_furnished=1&amp;min_bedrooms=1" rel="next">
#       <meta content="width=device-width,initial-scale=1" name="viewport">
#        <link href="//www.craigslist.org/styles/cl.css?v=d76fe4376346bd1b2503fb10181051a7" media="all" rel="stylesheet" type="text/css">
#         <link href="//www.craigslist.org/styles/search.css?v=27e1d4246df60da5ffd1146d59a8107e" media="all" rel="stylesheet" type="text/css">
#          <link href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339" media="all" rel="stylesheet" type="text/css">
#           <link href="//www.craigslist.org/js/postings-concat.min.js?v=5fba2d5d8f63b179eb3603dbc3d6504c" rel="prefetch">
#            <link href="//www.craigslist.org/styles/leaflet.css?v=a3659216b188171f9645f20cd0b4e60e" media="all" rel="stylesheet" type="text/css">
#             <link href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8" media="all" rel="stylesheet" type="text/css">
#              <link href="//www.craigslist.org/styles/tocsmaps.css?v=0643bce4a898776e6e10a86823bab509" media="all" rel="stylesheet" type="text/css">
#               <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">
# <![endif]-->
#               <script type="text/javascript">
#                <!--
# var areaCountry = "US";
# var areaID = "1";
# var areaRegion = "CA";
# var catAbb = "apa";
# var countOfTotalText = "image {count} of {total}";
# var currencySymbol = "&#x0024;";
# var defaultView = "grid";
# var expiredFavIDs = null;
# var imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};
# var lessInfoText = "less info";
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var maxResults = 2500;
# var noImageText = "no image";
# var pID = null;
# var postalLat = null;
# var postalLon = null;
# var purveyorCategories = null;
# var searchDistance = null;
# var sectionAbb = "hhh";
# var sectionBase = "hhh";
# var showInfoText = "show info";
# var showMapTabs = 1;
# var showingBanished = 0;
# var showingFavorites = 0;
# var starHint = "save this post in your favorites list";
# var subarea = null;
# var zoomToPosting = null;
# -->
#               </script>
#               <!--[if lt IE 9]>
# <script src="//www.craigslist.org/js/html5shiv.min.js?v=c0739b14a84b052680cdee44fea07435" type="text/javascript" ></script>
#
# <script src="//www.craigslist.org/js/respond-fork.min.js?v=247e877d69233f6f77bff30aca7b5473" type="text/javascript" ></script>
#
# <![endif]-->
#               <!--[if lte IE 7]>
# <script src="//www.craigslist.org/js/json2.min.js?v=6e47a4bb061d538548771024390aa00b" type="text/javascript" ></script>
#
# <![endif]-->
#              </link>
#             </link>
#            </link>
#           </link>
#          </link>
#         </link>
#        </link>
#       </meta>
#      </link>
#     </link>
#    </link>
#   </meta>
#  </head>
#  <body class="search has-map en">
#   <script type="text/javascript">
#    <!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# -->
#   </script>
#   <section class="page-container" id="page-top">
#    <div class="bglogo">
#    </div>
#    <header class="global-header wide">
#     <a class="header-logo" href="/" name="logoLink">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <form action="/search/apa" class="breadcrumbs-form" data-action="/search/###/apa" id="breadcrumbform" method="get">
#       <input name="min_bedrooms" type="hidden" value="1">
#        <input name="is_furnished" type="hidden" value="1">
#         <ul class="breadcrumbs ">
#          <li class="crumb area">
#           <span class="no-js">
#            <a href="/">
#             SF bay area
#            </a>
#           </span>
#           <select class="js-only" id="areaAbb" name="areaAbb">
#            <option value="sfbay">
#             SF bay area
#            </option>
#            <option value="bakersfield">
#             bakersfield
#            </option>
#            <option value="chico">
#             chico
#            </option>
#            <option value="fresno">
#             fresno
#            </option>
#            <option value="goldcountry">
#             gold country
#            </option>
#            <option value="hanford">
#             hanford
#            </option>
#            <option value="mendocino">
#             mendocino co
#            </option>
#            <option value="merced">
#             merced
#            </option>
#            <option value="modesto">
#             modesto
#            </option>
#            <option value="monterey">
#             monterey
#            </option>
#            <option value="redding">
#             redding
#            </option>
#            <option value="reno">
#             reno
#            </option>
#            <option value="sacramento">
#             sacramento
#            </option>
#            <option value="slo">
#             san luis obispo
#            </option>
#            <option value="santamaria">
#             santa maria
#            </option>
#            <option value="stockton">
#             stockton
#            </option>
#            <option value="susanville">
#             susanville
#            </option>
#            <option value="visalia">
#             visalia-tulare
#            </option>
#            <option value="yubasutter">
#             yuba-sutter
#            </option>
#           </select>
#           <span class="breadcrumb-arrow">
#            &gt;
#           </span>
#          </li>
#          <li class="crumb subarea">
#           <select id="subArea" name="subArea">
#            <option selected="" value="">
#             all SF bay area
#            </option>
#            <option value="eby">
#             east bay
#            </option>
#            <option value="nby">
#             north bay
#            </option>
#            <option value="pen">
#             peninsula
#            </option>
#            <option value="sfc">
#             san francisco
#            </option>
#            <option value="scz">
#             santa cruz
#            </option>
#            <option value="sby">
#             south bay
#            </option>
#           </select>
#           <span class="breadcrumb-arrow">
#            &gt;
#           </span>
#          </li>
#          <li class="crumb section">
#           <select id="catAbb" name="catAbb">
#            <option value="ccc">
#             community
#            </option>
#            <option value="eee">
#             events
#            </option>
#            <option value="sss">
#             for sale
#            </option>
#            <option value="ggg">
#             gigs
#            </option>
#            <option selected="" value="hhh">
#             housing
#            </option>
#            <option value="jjj">
#             jobs
#            </option>
#            <option value="ppp">
#             personals
#            </option>
#            <option value="rrr">
#             resumes
#            </option>
#            <option value="bbb">
#             services
#            </option>
#           </select>
#           <span class="breadcrumb-arrow">
#            &gt;
#           </span>
#          </li>
#          <li class="crumb category">
#           <select class="js-only" id="subcatAbb">
#            <option value="hhh">
#             all
#            </option>
#            <option value="hou">
#             apts wanted
#            </option>
#            <option selected="" value="apa">
#             apts/housing for rent
#            </option>
#            <option value="swp">
#             housing swap
#            </option>
#            <option value="off">
#             office &amp; commercial
#            </option>
#            <option value="prk">
#             parking &amp; storage
#            </option>
#            <option value="reb">
#             real estate - by broker
#            </option>
#            <option value="reo">
#             real estate - by owner
#            </option>
#            <option value="rew">
#             real estate wanted
#            </option>
#            <option value="roo">
#             rooms &amp; shares
#            </option>
#            <option value="sha">
#             rooms wanted
#            </option>
#            <option value="sbw">
#             sublet/temp wanted
#            </option>
#            <option value="sub">
#             sublets &amp; temporary
#            </option>
#            <option value="vac">
#             vacation rentals
#            </option>
#           </select>
#           <span class="no-js">
#            apts/housing for rent
#           </span>
#           <span class="breadcrumb-arrow">
#            &gt;
#           </span>
#          </li>
#          <li class="crumb no-js">
#           <input type="submit" value="go">
#           </input>
#          </li>
#         </ul>
#        </input>
#       </input>
#      </form>
#     </nav>
#     <div class="userlinks">
#      <ul class="user-actions">
#       <li class="user post">
#        <a href="https://post.craigslist.org/c/sfo">
#         post
#        </a>
#       </li>
#       <li class="user account">
#        <a href="https://accounts.craigslist.org/login/home">
#         account
#        </a>
#       </li>
#      </ul>
#      <ul class="user-favs-discards">
#       <li class="user">
#        <div class="favorites">
#         <a class="favlink" href="#">
#          <span aria-hidden="true" class="icon icon-star fav">
#          </span>
#          <span class="fav-number">
#           0
#          </span>
#          <span class="fav-label">
#           favorites
#          </span>
#         </a>
#        </div>
#       </li>
#       <li class="user discards">
#        <form action="/favorites" class="unfavform js-only" method="POST">
#         <div class="to-banish-page">
#          <input class="lastLink" name="lastLink" type="hidden" value="//sfbay.craigslist.org/search/apa?is_furnished=1&amp;min_bedrooms=1">
#           <input class="lastTitle" name="lastTitle" type="hidden" value="SF bay area apts/housing for rent  - craigslist">
#            <input class="unfaves" name="fl" type="hidden">
#             <input name="uf" type="hidden" value="1">
#              <a class="to-banish-page-link" href="#">
#               <span aria-hidden="true" class="icon icon-trash red">
#               </span>
#               <span class="banished_count">
#                0
#               </span>
#               <span class="discards-label">
#                hidden
#               </span>
#              </a>
#             </input>
#            </input>
#           </input>
#          </input>
#         </div>
#        </form>
#       </li>
#      </ul>
#     </div>
#    </header>
#    <header class="global-header narrow">
#     <a class="header-logo" href="/">
#      CL
#     </a>
#     <nav class="breadcrumbs-container">
#      <ul class="breadcrumbs">
#       SF bay area            &gt;
#
# apts/housing for rent
#      </ul>
#     </nav>
#     <span class="linklike show-wide-header">
#      ...
#     </span>
#    </header>
#    <form action="/search/apa" class="search-form" id="searchform">
#     <div class="querybox">
#      <div class="form-tab js-only">
#       <span class="search-open" title="hide search">
#        «
#       </span>
#       <span class="search-closed" title="show search">
#        »
#       </span>
#      </div>
#      <input autocapitalize="off" autocomplete="off" autocorrect="off" class="flatinput ui-autocomplete-input" data-autocomplete="search" id="query" name="query" placeholder="search apts/housing for rent" type="text" value="">
#       <button class="searchbtn" type="submit">
#        <span aria-hidden="true" class="icon icon-search">
#        </span>
#        <span class="screen-reader-text">
#         press to search craigslist
#        </span>
#       </button>
#       <div class="savealert">
#        <a class="saveme" data-action="save" href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Fsfbay%252Ecraigslist%252Eorg%252Fsearch%252Fapa%253Fis%255Ffurnished%253D1%2526min%255Fbedrooms%253D1" title="save this search">
#         save search
#        </a>
#       </div>
#      </input>
#     </div>
#     <div class="search-options-container">
#      <h2 class="search-options-header linklike">
#       <div aria-hidden="true" class="icon icon-toggle-gear">
#       </div>
#       options
#       <span class="options-close">
#        close
#       </span>
#      </h2>
#      <input id="excats" name="excats" type="hidden">
#       <div class="search-options">
#        <div class="searchgroup categories">
#         <div class="cattitle">
#          <a class="reset" href="/search/apa" title="clear all search parameters">
#           apts/housing for rent
#          </a>
#         </div>
#        </div>
#        <input name="userid" type="hidden" value=""/>
#        <div class="searchgroup">
#         <ul>
#          <li>
#           <label class="srchType">
#            <input name="srchType" type="checkbox" value="T">
#             search titles only
#            </input>
#           </label>
#          </li>
#          <li>
#           <label class="hasPic">
#            <input class="autosubmit" name="hasPic" type="checkbox" value="1">
#             has image
#            </input>
#           </label>
#          </li>
#          <li>
#           <label class="postedToday">
#            <input class="autosubmit" name="postedToday" type="checkbox" value="1">
#             posted today
#            </input>
#           </label>
#          </li>
#          <li>
#           <label class="bundleDuplicates">
#            <input class="autosubmit" name="bundleDuplicates" type="checkbox" value="1">
#             bundle duplicates
#            </input>
#           </label>
#          </li>
#          <li>
#           <label class="searchNearby">
#            <input class="autosubmit" name="searchNearby" type="checkbox" value="1">
#             include nearby areas
#            </input>
#           </label>
#          </li>
#         </ul>
#         <ul class="js-only nearbyAreas ">
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_17" name="nearbyArea" type="checkbox" value="63"/>
#            bakersfield, CA
#            <small>
#             (bak)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_9" name="nearbyArea" type="checkbox" value="187"/>
#            chico, CA
#            <small>
#             (chc)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_8" name="nearbyArea" type="checkbox" value="43"/>
#            fresno / madera
#            <small>
#             (fre)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_5" name="nearbyArea" type="checkbox" value="373"/>
#            gold country
#            <small>
#             (gld)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_10" name="nearbyArea" type="checkbox" value="709"/>
#            hanford-corcoran
#            <small>
#             (hnf)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_18" name="nearbyArea" type="checkbox" value="189"/>
#            humboldt county
#            <small>
#             (hmb)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_7" name="nearbyArea" type="checkbox" value="454"/>
#            mendocino county
#            <small>
#             (mdo)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_4" name="nearbyArea" type="checkbox" value="285"/>
#            merced, CA
#            <small>
#             (mer)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_2" name="nearbyArea" type="checkbox" value="96"/>
#            modesto, CA
#            <small>
#             (mod)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_1" name="nearbyArea" type="checkbox" value="102"/>
#            monterey bay
#            <small>
#             (mtb)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_15" name="nearbyArea" type="checkbox" value="188"/>
#            redding, CA
#            <small>
#             (rdd)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_13" name="nearbyArea" type="checkbox" value="92"/>
#            reno / tahoe
#            <small>
#             (rno)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_3" name="nearbyArea" type="checkbox" value="12"/>
#            sacramento
#            <small>
#             (sac)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_11" name="nearbyArea" type="checkbox" value="191"/>
#            san luis obispo
#            <small>
#             (slo)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_19" name="nearbyArea" type="checkbox" value="62"/>
#            santa barbara
#            <small>
#             (sba)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_14" name="nearbyArea" type="checkbox" value="710"/>
#            santa maria, CA
#            <small>
#             (smx)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_20" name="nearbyArea" type="checkbox" value="708"/>
#            siskiyou county
#            <small>
#             (ssk)
#            </small>
#           </label>
#          </li>
#          <li class="">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_0" name="nearbyArea" type="checkbox" value="97"/>
#            stockton, CA
#            <small>
#             (stk)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_16" name="nearbyArea" type="checkbox" value="707"/>
#            susanville, CA
#            <small>
#             (ssn)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_3">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_21" name="nearbyArea" type="checkbox" value="208"/>
#            ventura county
#            <small>
#             (oxr)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_2">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_12" name="nearbyArea" type="checkbox" value="346"/>
#            visalia-tulare
#            <small>
#             (vis)
#            </small>
#           </label>
#          </li>
#          <li class="nearbyZone nearbyZone_1">
#           <label class="nearby">
#            <input class="use-id nearbyArea" disabled="disabled" id="nearbyArea_6" name="nearbyArea" type="checkbox" value="456"/>
#            yuba-sutter, CA
#            <small>
#             (ybs)
#            </small>
#           </label>
#          </li>
#          <li>
#           <span class="nextNearbyZone linklike" data-zone="1">
#            + show
#            <span id="nearbyNumber">
#             22
#            </span>
#            more...
#           </span>
#          </li>
#         </ul>
#        </div>
#        <div class="searchgroup">
#         <span class="searchfieldlabel">
#          miles from zip
#         </span>
#         <input class="flatinput searchInput search_distance" inputmode="numeric" max="200" min="0" name="search_distance" placeholder="miles" size="3" type="number" value=""/>
#         <input class="flatinput searchInput postal" name="postal" placeholder="from zip" size="7" type="text" value="">
#         </input>
#        </div>
#        <div class="searchgroup minmax ">
#         <span class="searchfieldlabel">
#          price
#         </span>
#         <input class="flatinput min" name="min_price" placeholder="min" title="whole number, no letters or symbols" type="tel" value="">
#          <input class="flatinput max" name="max_price" placeholder="max" title="whole number, no letters or symbols" type="tel" value="">
#          </input>
#         </input>
#        </div>
#        <div class="searchgroup bed-bath-selects">
#         <span class="searchfieldlabel">
#          bedrooms
#         </span>
#         <select class="autosubmit" name="min_bedrooms">
#          <option value="">
#           min
#          </option>
#          <option selected="selected" value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#         -
#         <select class="autosubmit" name="max_bedrooms">
#          <option value="">
#           max
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup bed-bath-selects">
#         <span class="searchfieldlabel">
#          bathrooms
#         </span>
#         <select class="autosubmit" name="min_bathrooms">
#          <option value="">
#           min
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#         -
#         <select class="autosubmit" name="max_bathrooms">
#          <option value="">
#           max
#          </option>
#          <option value="1">
#           1
#          </option>
#          <option value="2">
#           2
#          </option>
#          <option value="3">
#           3
#          </option>
#          <option value="4">
#           4
#          </option>
#          <option value="5">
#           5
#          </option>
#          <option value="6">
#           6
#          </option>
#          <option value="7">
#           7
#          </option>
#          <option value="8">
#           8
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup minmax ">
#         <span class="searchfieldlabel">
#          ft
#          <sup>
#           2
#          </sup>
#         </span>
#         <input class="flatinput min" name="minSqft" placeholder="min" title="whole number, no letters or symbols" type="tel" value="">
#          <input class="flatinput max" name="maxSqft" placeholder="max" title="whole number, no letters or symbols" type="tel" value="">
#          </input>
#         </input>
#        </div>
#        <div class="searchgroup">
#         <span class="searchfieldlabel">
#          availability
#         </span>
#         <select class="autosubmit" name="availabilityMode">
#          <option value="0">
#           all dates
#          </option>
#          <option value="1">
#           within 30 days
#          </option>
#          <option value="2">
#           beyond 30 days
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup">
#         <label class="pets_cat">
#          <input class="autosubmit" name="pets_cat" type="checkbox" value="1"/>
#          cats ok
#         </label>
#         <br/>
#         <label class="pets_dog">
#          <input class="autosubmit" name="pets_dog" type="checkbox" value="1"/>
#          dogs ok
#         </label>
#         <br/>
#         <label class="is_furnished">
#          <input checked="checked" class="autosubmit" name="is_furnished" type="checkbox" value="1"/>
#          furnished
#         </label>
#         <br/>
#         <label class="no_smoking">
#          <input class="autosubmit" name="no_smoking" type="checkbox" value="1"/>
#          no smoking
#         </label>
#         <br/>
#         <label class="wheelchaccess">
#          <input class="autosubmit" name="wheelchaccess" type="checkbox" value="1"/>
#          wheelchair access
#         </label>
#         <br/>
#        </div>
#        <div class="searchgroup">
#         <div class="search-attribute hide-list" data-attr="housing_type">
#          <div class="title linklike ">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           housing type
#          </div>
#          <ul class="list">
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="housing_type_1" name="housing_type" type="checkbox" value="1"/>
#             apartment
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="housing_type_2" name="housing_type" type="checkbox" value="2"/>
#             condo
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="housing_type_3" name="housing_type" type="checkbox" value="3"/>
#             cottage/cabin
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="housing_type_4" name="housing_type" type="checkbox" value="4"/>
#             duplex
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="housing_type_5" name="housing_type" type="checkbox" value="5"/>
#             flat
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="housing_type_6" name="housing_type" type="checkbox" value="6"/>
#             house
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="housing_type_7" name="housing_type" type="checkbox" value="7"/>
#             in-law
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="housing_type_8" name="housing_type" type="checkbox" value="8"/>
#             loft
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="housing_type_9" name="housing_type" type="checkbox" value="9"/>
#             townhouse
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="housing_type_10" name="housing_type" type="checkbox" value="10"/>
#             manufactured
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="housing_type_11" name="housing_type" type="checkbox" value="11"/>
#             assisted living
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="housing_type_12" name="housing_type" type="checkbox" value="12"/>
#             land
#            </label>
#           </li>
#           <li class="selectall js-only ">
#            <span class="all">
#             select all
#            </span>
#            <span class="none">
#             deselect all
#            </span>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="laundry">
#          <div class="title linklike ">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           laundry
#          </div>
#          <ul class="list">
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="laundry_1" name="laundry" type="checkbox" value="1"/>
#             w/d in unit
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="laundry_4" name="laundry" type="checkbox" value="4"/>
#             w/d hookups
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="laundry_2" name="laundry" type="checkbox" value="2"/>
#             laundry in bldg
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="laundry_3" name="laundry" type="checkbox" value="3"/>
#             laundry on site
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="laundry_5" name="laundry" type="checkbox" value="5"/>
#             no laundry on site
#            </label>
#           </li>
#          </ul>
#         </div>
#         <div class="search-attribute hide-list" data-attr="parking">
#          <div class="title linklike ">
#           <span class="plus">
#            ▸
#           </span>
#           <span class="minus">
#            ▾
#           </span>
#           parking
#          </div>
#          <ul class="list">
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="parking_1" name="parking" type="checkbox" value="1"/>
#             carport
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="parking_2" name="parking" type="checkbox" value="2"/>
#             attached garage
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="parking_3" name="parking" type="checkbox" value="3"/>
#             detached garage
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="parking_4" name="parking" type="checkbox" value="4"/>
#             off-street parking
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="parking_5" name="parking" type="checkbox" value="5"/>
#             street parking
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="parking_6" name="parking" type="checkbox" value="6"/>
#             valet parking
#            </label>
#           </li>
#           <li class="checkbox ">
#            <label>
#             <input class="multi_checkbox" id="parking_7" name="parking" type="checkbox" value="7"/>
#             no parking
#            </label>
#           </li>
#           <li class="selectall js-only ">
#            <span class="all">
#             select all
#            </span>
#            <span class="none">
#             deselect all
#            </span>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="searchgroup">
#         <div class="label">
#          open house date
#         </div>
#         <select class="autosubmit" id="sale_date" name="sale_date">
#          <option>
#          </option>
#          <option value="2017-08-04">
#           aug 4 - today
#          </option>
#          <option value="2017-08-05">
#           aug 5 - tomorrow
#          </option>
#          <option value="2017-08-06">
#           aug 6 - sunday
#          </option>
#          <option value="2017-08-07">
#           aug 7 - monday
#          </option>
#          <option value="2017-08-08">
#           aug 8 - tuesday
#          </option>
#          <option value="2017-08-09">
#           aug 9 - wednesday
#          </option>
#          <option value="2017-08-10">
#           aug 10 - thursday
#          </option>
#          <option value="2017-08-11">
#           aug 11 - friday
#          </option>
#          <option value="2017-08-12">
#           aug 12 - saturday
#          </option>
#          <option value="2017-08-13">
#           aug 13 - sunday
#          </option>
#          <option value="2017-08-14">
#           aug 14 - monday
#          </option>
#          <option value="2017-08-15">
#           aug 15 - tuesday
#          </option>
#          <option value="2017-08-16">
#           aug 16 - wednesday
#          </option>
#          <option value="2017-08-17">
#           aug 17 - thursday
#          </option>
#          <option value="2017-08-18">
#           aug 18 - friday
#          </option>
#          <option value="2017-08-19">
#           aug 19 - saturday
#          </option>
#          <option value="2017-08-20">
#           aug 20 - sunday
#          </option>
#          <option value="2017-08-21">
#           aug 21 - monday
#          </option>
#          <option value="2017-08-22">
#           aug 22 - tuesday
#          </option>
#          <option value="2017-08-23">
#           aug 23 - wednesday
#          </option>
#          <option value="2017-08-24">
#           aug 24 - thursday
#          </option>
#          <option value="2017-08-25">
#           aug 25 - friday
#          </option>
#          <option value="2017-08-26">
#           aug 26 - saturday
#          </option>
#          <option value="2017-08-27">
#           aug 27 - sunday
#          </option>
#          <option value="2017-08-28">
#           aug 28 - monday
#          </option>
#          <option value="2017-08-29">
#           aug 29 - tuesday
#          </option>
#          <option value="2017-08-30">
#           aug 30 - wednesday
#          </option>
#          <option value="2017-08-31">
#           aug 31 - thursday
#          </option>
#         </select>
#        </div>
#        <div class="searchgroup resetsearch">
#         <a class="reset linklike" href="/search/apa" title="clear all search parameters">
#          reset
#         </a>
#         <button class="searchlink linklike" type="submit">
#          update search
#         </button>
#        </div>
#       </div>
#      </input>
#     </div>
#     <div class="search-legend">
#      <div class="search-view js-only">
#       <div aria-expanded="false" aria-label="view options" class="dropdown dropdown-icons dropdown-arrows dropdown-view" role="toolbar">
#        <ul class="dropdown-list">
#         <li class="dropdown-item mode sel">
#          <button data-selection="list" id="listview" title="show results in a list">
#           <span class="view-list icon">
#           </span>
#           list
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#         <li class="dropdown-item mode">
#          <button data-selection="pic" id="picview" title="show results in a list with thumbnail pictures">
#           <span class="view-thumb icon">
#           </span>
#           thumb
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#         <li class="dropdown-item mode">
#          <button data-selection="grid" id="gridview" title="show results side-by-side with larger pictures">
#           <span class="view-gallery icon">
#           </span>
#           gallery
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#         <li class="dropdown-item mode">
#          <button data-selection="map" id="mapview" title="show results on a map">
#           <span class="view-map icon">
#           </span>
#           map
#          </button>
#          <span class="toggle-arrow">
#          </span>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="search-sort">
#       <div aria-expanded="false" aria-label="sort options" class="dropdown dropdown-sort dropdown-arrows" data-default-sort="date" role="toolbar">
#        <ul class="dropdown-list">
#         <li aria-selected="false" class="dropdown-item mode ">
#          <a data-selection="upcoming" href="/search/apa?sort=upcoming&amp;is_furnished=1&amp;min_bedrooms=1" title="show upcoming open houses">
#           upcoming
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#         <li aria-selected="true" class="dropdown-item mode sel">
#          <a data-selection="date" href="/search/apa?sort=date&amp;is_furnished=1&amp;min_bedrooms=1" title="show newest matches first">
#           newest
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#         <li aria-selected="false" class="dropdown-item mode ">
#          <a data-selection="priceasc" href="/search/apa?sort=priceasc&amp;is_furnished=1&amp;min_bedrooms=1" title="sort by price, lowest to highest">
#           price ↑
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#         <li aria-selected="false" class="dropdown-item mode ">
#          <a data-selection="pricedsc" href="/search/apa?sort=pricedsc&amp;is_furnished=1&amp;min_bedrooms=1" title="sort by price, highest to lowest">
#           price ↓
#           <span class="toggle-arrow">
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="paginator buttongroup firstpage">
#       <span class="resulttotal">
#        <span class="for-map">
#         displaying
#         <span class="displaycountShow">
#          ...
#         </span>
#         postings
#        </span>
#       </span>
#       <span class="buttons">
#        <a class="button first" href="/search/apa?is_furnished=1&amp;min_bedrooms=1" title="first page">
#         &lt;&lt;
#        </a>
#        <span class="button first" title="first page">
#         &lt;&lt;
#        </span>
#        <a class="button prev" href="/search/apa?is_furnished=1&amp;min_bedrooms=1" title="previous page">
#         &lt; prev
#        </a>
#        <span class="button prev" title="previous page">
#         &lt; prev
#        </span>
#        <span class="button pagenum">
#         <span class="range">
#          <span class="rangeFrom">
#           1
#          </span>
#          -
#          <span class="rangeTo">
#           120
#          </span>
#         </span>
#         /
#         <span class="totalcount">
#          1104
#         </span>
#        </span>
#        <a class="button next" href="/search/apa?s=120&amp;is_furnished=1&amp;min_bedrooms=1" title="next page">
#         next &gt;
#        </a>
#        <span class="button next" title="next page">
#         next &gt;
#        </span>
#       </span>
#      </div>
#     </div>
#     <div class="content" id="sortable-results">
#      <section class="favlistsection">
#       <section class="favlistinfo">
#       </section>
#       <section class="banishlistinfo">
#       </section>
#      </section>
#      <div class="open-map-view-button">
#       <span>
#        see in map view
#       </span>
#      </div>
#      <div data-arealat="37.500000" data-arealon="-122.250000" id="mapcontainer">
#       <div id="noresult-overlay">
#       </div>
#       <div id="noresult-text">
#        <span class="message">
#         No mappable items found
#        </span>
#       </div>
#       <div class="loading" id="map">
#        <div class="close-full-screen-map-mode-button">
#         close fullscreen
#        </div>
#        <div class="close-map-view-button">
#         close map
#        </div>
#       </div>
#      </div>
#      <ul class="rows">
#       <li class="result-row" data-pid="6250272639">
#        <a class="result-image gallery" data-ids="1:00Z0Z_8eSVg8FYrXo,1:00O0O_51cU0fI6Qf4,1:00a0a_ePaKUOP6Y3d,1:00T0T_3lNG4IT2mix,1:00N0N_aQ6Z8ZOMGLB" href="/sby/apa/d/430-studio-with-walk-in-closet/6250272639.html">
#         <span class="result-price">
#          $1800
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2017-08-04 15:56" title="Fri 04 Aug 03:56:06 PM">
#          Aug  4
#         </time>
#         <a class="result-title hdrlnk" data-id="6250272639" href="/sby/apa/d/430-studio-with-walk-in-closet/6250272639.html">
#          430 Studio with Walk in Closet
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           $1800
#          </span>
#          <span class="housing">
#           1br -
#                     430ft
#           <sup>
#            2
#           </sup>
#           -
#          </span>
#          <span class="result-hood">
#           (san jose north)
#          </span>
#          <span class="result-tags">
#           pic
#           <span class="maptag" data-pid="6250272639">
#            map
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="6243862695">
#        <a class="result-image gallery" data-ids="1:00D0D_O5L2mCMMLL,1:00g0g_7urYG3yGoNb,1:00d0d_9Xe3euh2eqF,1:01111_4mYSO0dgqB5,1:00e0e_7FzdqoSvqHh,1:00N0N_40OfwwyLSZ4,1:00404_5uO1hIuNeLa,1:00A0A_lOLnkkqzTw4,1:00k0k_7i8JROsAE3X,1:00p0p_kGklj2x4ddt,1:01515_eLnO4Amq9cN,1:01616_lEaXlSeoM6x,1:00606_jzWn3a0SOBJ" href="/sby/apa/d/fully-furnished-1-bed-apt-in/6243862695.html">
#         <span class="result-price">
#          $3495
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2017-08-04 15:55" title="Fri 04 Aug 03:55:20 PM">
#          Aug  4
#         </time>
#         <a class="result-title hdrlnk" data-id="6243862695" href="/sby/apa/d/fully-furnished-1-bed-apt-in/6243862695.html">
#          Fully Furnished 1-Bed Apt in Sunnyvale! Parking, Laundry, Caltrain!
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           $3495
#          </span>
#          <span class="housing">
#           1br -
#          </span>
#          <span class="result-hood">
#           (sunnyvale)
#          </span>
#          <span class="result-tags">
#           pic
#           <span class="maptag" data-pid="6243862695">
#            map
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="6247211088" data-repost-of="6198052002">
#        <a class="result-image gallery" data-ids="1:00c0c_ctr2quz76Lj,1:00Q0Q_40355B9HM8B,1:00y0y_lr8T34zwb3T,1:00404_jcvfs79kzKp" href="/sfc/apa/d/5000-2br-2-bedroom15-bath/6247211088.html">
#         <span class="result-price">
#          $5000
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2017-08-04 15:54" title="Fri 04 Aug 03:54:16 PM">
#          Aug  4
#         </time>
#         <a class="result-title hdrlnk" data-id="6247211088" href="/sfc/apa/d/5000-2br-2-bedroom15-bath/6247211088.html">
#          $5000 / 2br - 2 Bedroom/1.5 Bath with Showstopping Views Available (fi
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           $5000
#          </span>
#          <span class="housing">
#           2br -
#          </span>
#          <span class="result-hood">
#           (financial district)
#          </span>
#          <span class="result-tags">
#           pic
# ...
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="6249771658" data-repost-of="6197965622">
#        <a class="result-image gallery" data-ids="1:00707_9lwekx8r1CQ,1:01616_4uWxnUVa3Fs,1:00H0H_7Z9GnAC1vxO,1:00r0r_chIyUEDgUz8,1:00q0q_7h6QZ8uh2NX,1:00F0F_kYH2kk5YcmT,1:00t0t_DECV6Tq925,1:01414_7jURRzfRHbe,1:00r0r_68yhKf6xbXt,1:00U0U_32W1kvyq99H,1:01414_fhxg3uNxQJn,1:00f0f_689MOhYJykM,1:01111_aShrs1n3yjz,1:00Q0Q_eM5J4jO2rY6,1:00B0B_j4qUvMMr3BK,1:00Z0Z_6ek9IQ5YdSn" href="/sfc/apa/d/one-bedroom-one-bath-condo/6249771658.html">
#         <span class="result-price">
#          $3795
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2017-08-04 10:25" title="Fri 04 Aug 10:25:55 AM">
#          Aug  4
#         </time>
#         <a class="result-title hdrlnk" data-id="6249771658" href="/sfc/apa/d/one-bedroom-one-bath-condo/6249771658.html">
#          One Bedroom One Bath Condo W/Pkg. North Waterfront Furnished
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           $3795
#          </span>
#          <span class="housing">
#           1br -
#          </span>
#          <span class="result-hood">
#           (north beach / telegraph hill)
#          </span>
#          <span class="result-tags">
#           pic
#           <span class="maptag" data-pid="6249771658">
#            map
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="6249768661" data-repost-of="5277213781">
#        <a class="result-image gallery" data-ids="1:00L0L_4N4EajX3icL,1:00e0e_GyElPkgIJj,1:00v0v_1dWgs7DVdaI,1:00404_byDCk7KC7TM,1:01212_752WdGfJfK,1:00j0j_dYn0OdAwwbw,1:00707_dFesXOOngQo,1:00a0a_bdSwW7ZgBHI,1:00F0F_5sSwH0T7GZV" href="/eby/apa/d/short-term-housing/6249768661.html">
#         <span class="result-price">
#          $2250
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2017-08-04 10:24" title="Fri 04 Aug 10:24:10 AM">
#          Aug  4
#         </time>
#         <a class="result-title hdrlnk" data-id="6249768661" href="/eby/apa/d/short-term-housing/6249768661.html">
#          Short term housing
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           $2250
#          </span>
#          <span class="housing">
#           1br -
#                     650ft
#           <sup>
#            2
#           </sup>
#           -
#          </span>
#          <span class="result-hood">
#           (concord / pleasant hill / martinez)
#          </span>
#          <span class="result-tags">
#           pic
#           <span class="maptag" data-pid="6249768661">
#            map
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="6249752056" data-repost-of="5705309284">
#        <a class="result-image gallery" data-ids="1:00F0F_eX8h2D4NtOM,1:01515_imVSJ607uei,1:01515_3xVm0gF9gRC,1:01111_jiuzsYiaLjI,1:00Q0Q_3A1qXXDRb7J,1:00B0B_1fyJxy21v8r" href="/sfc/apa/d/corner-unit-1-bedroom-in-the/6249752056.html">
#         <span class="result-price">
#          $3399
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2017-08-04 10:20" title="Fri 04 Aug 10:20:28 AM">
#          Aug  4
#         </time>
#         <a class="result-title hdrlnk" data-id="6249752056" href="/sfc/apa/d/corner-unit-1-bedroom-in-the/6249752056.html">
#          Corner Unit 1 bedroom in the heart of the Marina
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           $3399
#          </span>
#          <span class="housing">
#           1br -
#          </span>
#          <span class="result-hood">
#           (marina / cow hollow)
#          </span>
#          <span class="result-tags">
#           pic
#           <span class="maptag" data-pid="6249752056">
#            map
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#       <li class="result-row" data-pid="6242482277" data-repost-of="6185007780">
#        <a class="result-image gallery" data-ids="1:00E0E_6P9spULFQZP,1:00h0h_dpHUQV3IrCR,1:00Q0Q_dYzE5iTzsew,1:00J0J_4YVsBH4nsI4,1:00l0l_cdqKlII8rXG,1:00L0L_3PkDfw6Yshv,1:01010_l2cD6HwLtQ9,1:00R0R_bFst4yNxXoy,1:00000_LTEnUAi6JJ,1:00L0L_75dKbsi69fR" href="/sfc/apa/d/the-infinity-large-1bd1ba/6242482277.html">
#         <span class="result-price">
#          $4500
#         </span>
#        </a>
#        <p class="result-info">
#         <span class="icon icon-star" role="button">
#          <span class="screen-reader-text">
#           favorite this post
#          </span>
#         </span>
#         <time class="result-date" datetime="2017-08-04 10:18" title="Fri 04 Aug 10:18:46 AM">
#          Aug  4
#         </time>
#         <a class="result-title hdrlnk" data-id="6242482277" href="/sfc/apa/d/the-infinity-large-1bd1ba/6242482277.html">
#          THE INFINITY- Large 1BD1BA Condo w/ Pkg. *Furnished or Unfurnished
#         </a>
#         <span class="result-meta">
#          <span class="result-price">
#           $4500
#          </span>
#          <span class="housing">
#           1br -
#          </span>
#          <span class="result-hood">
#           (SOMA / south beach)
#          </span>
#          <span class="result-tags">
#           pic
#           <span class="maptag" data-pid="6242482277">
#            map
#           </span>
#          </span>
#          <span class="banish icon icon-trash" role="button">
#           <span class="screen-reader-text">
#            hide this posting
#           </span>
#          </span>
#          <span aria-hidden="true" class="unbanish icon icon-trash red" role="button">
#          </span>
#          <a class="restore-link" href="#">
#           <span class="restore-narrow-text">
#            restore
#           </span>
#           <span class="restore-wide-text">
#            restore this posting
#           </span>
#          </a>
#         </span>
#        </p>
#       </li>
#      </ul>
#     </div>
#     <div class="search-legend bottom">
#      <div class="search-view">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="search-sort">
#       <span class="buttongroup">
#        <a class="backtotop button" href="#page-top">
#         ^ back to top
#        </a>
#       </span>
#      </div>
#      <div class="paginator buttongroup firstpage">
#       <span class="resulttotal">
#        <span class="for-map">
#         displaying
#         <span class="displaycountShow">
#          ...
#         </span>
#         postings
#        </span>
#       </span>
#       <span class="buttons">
#        <a class="button first" href="/search/apa?is_furnished=1&amp;min_bedrooms=1" title="first page">
#         &lt;&lt;
#        </a>
#        <span class="button first" title="first page">
#         &lt;&lt;
#        </span>
#        <a class="button prev" href="/search/apa?is_furnished=1&amp;min_bedrooms=1" title="previous page">
#         &lt; prev
#        </a>
#        <span class="button prev" title="previous page">
#         &lt; prev
#        </span>
#        <span class="button pagenum">
#         <span class="range">
#          <span class="rangeFrom">
#           1
#          </span>
#          -
#          <span class="rangeTo">
#           120
#          </span>
#         </span>
#         /
#         <span class="totalcount">
#          1104
#         </span>
#        </span>
#        <a class="button next" href="/search/apa?s=120&amp;is_furnished=1&amp;min_bedrooms=1" title="next page">
#         next &gt;
#        </a>
#        <span class="button next" title="next page">
#         next &gt;
#        </span>
#       </span>
#      </div>
#     </div>
#     <section class="blurbs">
#     </section>
#     <div id="floater">
#      <img alt="" class="loading" src="//www.craigslist.org/images/animated-spinny.gif">
#       <img alt="" class="payload" src="//www.craigslist.org/images/animated-spinny.gif">
#       </img>
#      </img>
#     </div>
#    </form>
#    <div class="slidemessage">
#     <span class="fave">
#      <span class="star">
#      </span>
#      favorited
#     </span>
#     <span class="unfave">
#      <span class="star">
#      </span>
#      no longer favorited
#     </span>
#     <span class="hide">
#      <span class="trash">
#      </span>
#      hidden
#     </span>
#     <span class="unhide">
#      <span class="trash">
#      </span>
#      no longer hidden
#     </span>
#    </div>
#    <footer>
#     <span class="rss">
#      <a class="l" href="https://sfbay.craigslist.org/search/apa?format=rss&amp;is_furnished=1&amp;min_bedrooms=1">
#       RSS
#      </a>
#      <a href="https://www.craigslist.org/about/rss">
#       (?)
#      </a>
#      <br>
#      </br>
#     </span>
#     <ul class="clfooter">
#      <li>
#       ©
#       <span class="desktop">
#        craigslist
#       </span>
#       <span class="mobile">
#        CL
#       </span>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/help/">
#        help
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/scams">
#        safety
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/privacy.policy">
#        privacy
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://forums.craigslist.org/?forumID=8">
#        feedback
#       </a>
#      </li>
#      <li class="desktop">
#       <a href="https://www.craigslist.org/about/craigslist_is_hiring">
#        cl jobs
#       </a>
#      </li>
#      <li>
#       <a href="//www.craigslist.org/about/terms.of.use.en">
#        terms
#       </a>
#      </li>
#      <li>
#       <a href="https://www.craigslist.org/about/">
#        about
#       </a>
#      </li>
#      <li class="fsel desktop linklike" data-mode="mobile">
#       mobile
#      </li>
#      <li class="fsel mobile linklike" data-mode="regular">
#       desktop
#      </li>
#     </ul>
#    </footer>
#   </section>
#   <template id="gallerycarousel">
#    <div class="slider-info">
#    </div>
#    <div class="slider-back arrow">
#     &lt;
#    </div>
#    <div class="slider-forward arrow">
#     &gt;
#    </div>
#   </template>
#   <script src="//www.craigslist.org/js/general-concat.min.js?v=65297564f2cbfb1a1ad83a34bb9646b1" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--
#         var iframe = document.createElement('iframe');
#         iframe.style.display = 'none';
#         iframe.src = '//www.' + CL.url.baseDomain + '/static/localstorage.html?v=51a29e41f8e978141e4085ed4a77d170';
#         document.body.insertBefore(iframe, null);
#     -->
#   </script>
#   <script id="clustertemplate" type="text/template">
#    <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     unhide
#                 </span>
#             </span>
#         </div>
#     </li>
#   </script>
#   <script id="postingtemplate" type="text/template">
#    <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">hide this posting</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">unhide</span>
#                         unhide
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lt;</span><span class="slider-info"></span><span class="slider-forward arrow">&gt;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <div class="timecontainer"></div>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
#   </script>
#   <script id="popuptemplate" type="text/template">
#    <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
#   </script>
#   <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=a21d5db615724de9d6e3511c3a9b2169" type="text/javascript">
#   </script>
#   <script src="//www.craigslist.org/js/search-concat.min.js?v=869e9a1b9b9a2ae3a18c238c8d4e198c" type="text/javascript">
#   </script>
#  </body>
# </html>

# %% [markdown]
# ## STEP 02: Get neccessary information from the web
# We can see that every single post will be stored in <b>p</b> attribute with class <b>result-info</b><br>
# From that observation, we can retrieve all information by getting from this attribute.

# %%
apts = html.find_all('p', attrs={'class':'result-info'})
print(len(apts))
# Out:
# 120

# %% [markdown]
# <b>apts</b> is a list of 120 renting objects. We can take one out for our sample. We work on this sample to have the sense how to apply all these things to the whole list.

# %%
this_aprt = apts[15]
print(this_aprt)
# Out:
# <p class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2017-08-04 14:42" title="Fri 04 Aug 02:42:28 PM">Aug  4</time>
# <a class="result-title hdrlnk" data-id="6214700497" href="/sfc/apa/d/3ba-furnished-great-nhood-2/6214700497.html">3ba, Furnished, Great N'hood, 2 car Garage,</a>
# <span class="result-meta">
# <span class="result-price">$13975</span>
# <span class="housing">
#                     4br -
#                 </span>
# <span class="result-hood"> (marina / cow hollow)</span>
# <span class="result-tags">
#                     pic
#                     <span class="maptag" data-pid="6214700497">map</span>
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# <span aria-hidden="true" class="unbanish icon icon-trash red" role="button"></span>
# <a class="restore-link" href="#">
# <span class="restore-narrow-text">restore</span>
# <span class="restore-wide-text">restore this posting</span>
# </a>
# </span>
# </p>

# %% [markdown]
# ### We get the information about number of bedroom and apartment's area

# %%
size = this_aprt.find_all(attrs={'class':'housing'})[0].text
print(size)
# Out:
#                     4br -

# %% [markdown]
# ### We will create a function to get those information and store into apt_size and n_brs variables:

# %%
def size_brs(size):
    split_var = size.strip('\n ').strip('\n - ').split('-')
    if len(split_var) == 2:
        n_brs = split_var[0].replace('br', '')
        apt_size = split_var[1].replace('ft2', '')
    elif 'br' in split_var[0]:
        n_brs = split_var[0].replace('br', '')
        apt_size = np.nan
    elif 'ft2' in split_var[1]:
        apt_size = split_var[1].replace('ft2', '')
        n_brs = np.nan
    return float(apt_size), float(n_brs)

# %%
apt_size, n_brs = size_brs(size)

# %%
time = this_aprt.find('time')['datetime']
time = pd.to_datetime(time)

# %%
price = float(this_aprt.find('span', {'class':'result-price'}).text.strip('$'))

# %%
title = this_aprt.find('a', {'class':'result-title hdrlnk'}).text

# %%
link = this_aprt.find('a', {'class':'result-title hdrlnk'})['href']

# %% [markdown]
# ## STEP 03: Put everything into an array then we have done!
# We have all relevant information we need to know about apartments' rental price in SF Bay Area. We just display it to make sure that everything is correct.

# %%
print('\n'.join([str(i) for i in [apt_size, n_brs, time, price, title]]))
# Out:
# nan
# 4.0
# 2017-08-04 14:42:00
# 13975.0
# 3ba, Furnished, Great N'hood, 2 car Garage,

# %% [markdown]
# # Apply everything will did above to the whole list of rental objects.
# * Object: is every single apartment posted on Craigslist that we are working on.
# * Each page will show 120 objects by default.
# * We can iterate over 1000 objects to get the information

# %%
page_index = np.arange(0, 1000, 120)

# %%
def set_price(x): # Avoid getting None value
    price = x.find('span', {'class':'result-price'})
    if price is not None:
        price = float(price.text.strip('$'))
    else:
        price = np.nan
    return price

def set_time(x): # Avoid getting None value
    time = x.find('time')['datetime']
    if time is not None:
        time = pd.to_datetime(time)
    else:
        time = np.nan
    return time

# %% [markdown]
# ### Some notices in this step:
# * We need to have a delay when we query Craigslist because if we keep querying too often, our IP address will be blocked (to avoid DDoS attack). In this step, I set the delay time is 1 second for each query.
# * In params, <b>s</b> parameter indicates the page we are currently working on. By increasing this variable, we will iterate over 1000 objects via multiple pages.
# * After everything has done, we store the result into <b>result</b> array. This is the input data for us to put in pandas DataFrame for later analytics purpose.

# %%
import time as tp
result = []
for j in page_index:
    url_base = 'https://sfbay.craigslist.org/search/apa'
    params = dict(bedrooms=1, is_furnished=1,s=j)
    resq = requests.get(url_base, params=params)
    html = bs4(resq.text, 'html.parser')
    apts = html.find_all('p', attrs={'class':'result-info'})
    for this_aprt in apts:
        size = this_aprt.find_all(attrs={'class':'housing'})[0].text
        apt_size, n_brs = size_brs(size)
        time = set_time(this_aprt)
        price = set_price(this_aprt)
        title = this_aprt.find('a', {'class':'result-title hdrlnk'}).text
        link = this_aprt.find('a', {'class':'result-title hdrlnk'})['href']
        data = np.array([time, price, apt_size, n_brs,title, link])
        result.append(data)
    tp.sleep(1)

# %% [markdown]
# ### Put everything into Pandas DataFrame

# %%
col_names = ['time', 'price', 'size', 'brs', 'title', 'link']
result = pd.DataFrame(data=result, columns=col_names)
result.set_index('time')
result.head()
# Out:
#                  time   price    size  brs  \
# 0 2017-08-04 15:56:00  1800.0   430.0  1.0
# 1 2017-08-04 15:55:00  3495.0     NaN  1.0
# 2 2017-08-04 15:54:00  5000.0     NaN  2.0
# 3 2017-08-04 15:38:00  2000.0  1830.0  4.0
# 4 2017-08-04 15:35:00  6395.0  1300.0  4.0
#
#                                                title  \
# 0                     430 Studio with Walk in Closet
# 1  Fully Furnished 1-Bed Apt in Sunnyvale! Parkin...
# 2  $5000 / 2br - 2 Bedroom/1.5 Bath with Showstop...
# 3  It features a freshly painted large living room!!
# 4  Beautiful (furnished) 4bedroom-deck-wash/dryer...
#
#                                                 link
# 0  /sby/apa/d/430-studio-with-walk-in-closet/6250...
# 1  /sby/apa/d/fully-furnished-1-bed-apt-in/624386...
# 2  /sfc/apa/d/5000-2br-2-bedroom15-bath/624721108...
# 3  /nby/apa/d/it-features-freshly-painted/6250241...
# 4  /sfc/apa/d/beautiful-furnished-4bedroom/622199...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(12,10))
sns.distplot(result.price.dropna(),bins=np.arange(0, 10000, 100),color='red',axlabel='SF Bay Area - Apartment Rental Price ($)').set(xlim=(0, 12000))
# Out:
# [(0, 12000)]

# %% [markdown]
# ## The above plot is to show the distribution of rental prices of apartments in SF Bay Area
